# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelN601/cyp_2021/blob/main/CyP_03Dic2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejemplo 1

coleccion = [1,2,3,4,5]
for i in coleccion:
  print(f"El elemento: {i}")
# Out:
# El elemento: 1
# El elemento: 2
# El elemento: 3
# El elemento: 4

# %%
#Ejemplo 2

coleccion = {"Mario":20, "Mariana":19, "Yessica":14, "Luis":18}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
coleccion = {"Mario": 20, "Mariana":19, "Yessica":14, "Luis":18}
for i in coleccion:
  print(f"{i}->{coleccion[i]}")
# Out:
# Mario->20
# Mariana->19
# Yessica->14
# Luis->18

# %%
coleccion= {"Alejandro":20, "Mariana":19, "Yess":14, "Lidia":18}
for clave, valor in coleccion.items():
  print(f"{clave} -->{valor}")
# Out:
# Alejandro -->20
# Mariana -->19
# Yess -->14
# Lidia -->18

# %%
#Ejemplo 3 
email=False
for i in "arielgarcia@unam.mx":
  if (i=="@"):
    email=True
if email ==True:
    print("El email es correcto")
else:
    print("El email no es correcto")
# Out:
# El email es correcto

# %%
email=False
miEmail=input("Escribe tu correo electrónico:")
for i in miEmail:
  if (i=="@"):
    email=True
if email ==True:
    print("El email es correcto")
else:
    print("El email no es correcto")
# Out:
# Escribe tu correo electrónico:angel@hotmail.com
# El email es correcto

# %%
#For range

for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (10):
  print(f"valor de la variable {i}")
# Out:
# valor de la variable 0
# valor de la variable 1
# valor de la variable 2
# valor de la variable 3
# valor de la variable 4
# valor de la variable 5
# valor de la variable 6
# valor de la variable 7
# valor de la variable 8
# valor de la variable 9

# %%
#while 

i = 1
while 1 <=10:
  print("Ejecucion"+str(i))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# ...

# %%
#For-Range
for i in range(5):
  print("Hola")
# Out:
# Hola
# Hola
# Hola
# Hola
# Hola

# %%
for i in range(5):
  print(f"valor de la varieable es {i}")
# Out:
# valor de la varieable es 0
# valor de la varieable es 1
# valor de la varieable es 2
# valor de la varieable es 3
# valor de la varieable es 4

# %%
edad = int (input("Introduce tu edad:"))
while edad < 0:
  print("Has introducido una edad negativa, Intentantalo de nuevo")
  edad = int (input("Introduce tu edad:"))
print("Gracias por participar. Puede pasar")
print("Edad del aspirante"+str (edad))
# Out:
# Introduce tu edad:100
# Gracias por participar. Puede pasar
# Edad del aspirante100
