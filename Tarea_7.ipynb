# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelN601/cyp_2021/blob/main/Tarea_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problema 4.11
print("Ingrese el total de paises d Sur, Centro y Norteamerica")


TPS = int (input("Total de paises de America del sur "))
TPC = int (input("Total de paises de Centroamertica "))
TPN = int (input("Total de paises de Norteamerica "))


SUR = [1 for x in range(30)]
CENTRO = [1 for x in range(30)]
NORTE = [1 for x in range(30)]
AM = (TPS + TPC + TPN)
AMERICA = [0 for x in range(90)]


if 1 <= TPS <= 30 and 1 <= TPC <= 30 and 1 <= TPN <= 30:
  print("Ingrese los nombres de los paises de sudamenrica")
  I = 1
  while I <= TPS:
    print("Ingrese el nombre del pais", I)
    SUR[I] = (input(f"País {I} "))
    I += 1
  print("Ingrese los nombres de los paices de Centroamerica")
  I = 1
  while I <= TPC:
    print("Ingrese el nombre del pais", I)
    CENTRO[I] = (input(f"País {I} "))
    I += 1
  print("Ingrese los nombres de los paises de Norteamerica")
  I = 1
  while I <= TPN:
    print("Ingrese el nombre del pais", I)
    NORTE[I] = (input(f"País {I} "))
    I += 1 
  PS = 1
  PN = 1
  PC = 1
  PA = 0
  while PS <= TPS and PC <= TPC and PN <= TPN:
    PA += 1
    if SUR[PS] < CENTRO[PC] and SUR[PS] < NORTE[PN]:
      AMERICA[PA] = SUR[PS]
      PS += 1
    else:
      if CENTRO[PC] < NORTE [PN]:
        AMERICA[PA] = CENTRO[PC]
        PC += 1
      else:
        AMERICA[PA] = NORTE[PN]
        PN += 1    
  while PS <= TPS and PC <= TPC:
    PA += 1
    if SUR [PS] < CENTRO [PC]:
      AMERICA[PA] = SUR[PS]
      PS += 1
    else:
      AMERICA[PA] = CENTRO[PC]
      PC += 1 
  while PS <= TPS and PN <= TPN:
    PA += 1
    if SUR[PS] < NORTE[PN]:
      AMERICA[PA] = SUR[PS]
      PS += 1
    else:
      AMERICA[PA] = NORTE[PN]
      PN += 1     
  while PC <= TPC and PN <= TPN:
    PA += 1
    if CENTRO[PC] < NORTE [PN]:
      AMERICA[PA] = CENTRO[PC]
      PC += 1
    else:
      AMERICA[PA] = NORTE[PN]
      PN += 1

    
  while PS <= TPS:
    PA += 1
    AMERICA[PA] = SUR[PS]
    PS += 1
  while PC <= TPC:
    PA += 1
    AMERICA[PA] = CENTRO[PC]
    PC += 1
  while PN <= TPN:
    PA += 1
    AMERICA [PA] = NORTE[PN]
    PN += 1
  print("Arreglo America")
  I = 1
  while I <= PA:
    
    print(f"-",AMERICA[I])
    I += 1







else:
  print("Verifique el número de paises ingresados")
# Out:
# Ingrese el total de paises d Sur, Centro y Norteamerica
# Total de paises de America del sur 4
# Total de paises de Centroamertica 2
# Total de paises de Norteamerica 3
# Ingrese los nombres de los paises de sudamenrica
# Ingrese el nombre del pais 1
# País 1 Argentina
# Ingrese el nombre del pais 2
# País 2 Chile
# Ingrese el nombre del pais 3
# País 3 Colombia
# Ingrese el nombre del pais 4
# País 4 Ecuador
# Ingrese los nombres de los paices de Centroamerica
# Ingrese el nombre del pais 1
# País 1 Guatemala
# Ingrese el nombre del pais 2
# País 2 Costa Rica
# Ingrese los nombres de los paises de Norteamerica
# Ingrese el nombre del pais 1
# País 1 Mexico
# Ingrese el nombre del pais 2
# País 2 EU
# Ingrese el nombre del pais 3
# País 3 Canada
# Arreglo America
# - Argentina
# - Chile
# - Colombia
# - Ecuador
# - Guatemala
# - Costa Rica
# - Mexico
# - EU
# - Canada
